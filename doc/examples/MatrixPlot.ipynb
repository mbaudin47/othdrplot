# %% [markdown]
# # MatrixPlot

# %% [markdown]
# Demonstrate 2-dimensional matrix plot with OpenTURNS.

# %%
import os
import openturns as ot
from othdrplot import MatrixPlot

# %% [markdown]
# Load the csv data file.

# %%
fname = os.path.join(os.path.abspath(''), '../../tests/data/gauss-mixture.csv')
sample = ot.Sample.ImportFromCSVFile(fname)
sample
# Out:
# class=Sample name=C:\Users\c61372\Documents\GITHUB\othdrplot\doc\examples\../../tests/data/gauss-mixture.csv implementation=class=SampleImplementation name=C:\Users\c61372\Documents\GITHUB\othdrplot\doc\examples\../../tests/data/gauss-mixture.csv size=1000 dimension=2 description=[X0,X1] data=[[0.806851,-1.69008],[2.22223,-1.95101],[1.75679,-0.88062],...,[-0.144572,-1.75943],[0.812519,-2.3216],[-0.525143,2.01341]]

# %% [markdown]
# In order to run the algorithm, we first create the object with the sample.

# %%
mp = MatrixPlot(sample)

# %% [markdown]
# Then we use the `draw()` method. By default, the histogram is on the diagonal.

# %%
_ = mp.draw()

# %% [markdown]
# If the distribution is known or estimated from the data, it can be given to the class, which then draw it in the diagonal.

# %%
ks = ot.KernelSmoothing()
distribution = ks.build(sample)
mp = MatrixPlot(sample,distribution)
_ = mp.draw()

# %% [markdown]
# We load a 3D sample with 500 points.

# %%
fname = os.path.join(os.path.abspath(''), '../../tests/data/gauss-mixture-3D.csv')
sample = ot.Sample.ImportFromCSVFile(fname)
sample
# Out:
# class=Sample name=C:\Users\c61372\Documents\GITHUB\othdrplot\doc\examples\../../tests/data/gauss-mixture-3D.csv implementation=class=SampleImplementation name=C:\Users\c61372\Documents\GITHUB\othdrplot\doc\examples\../../tests/data/gauss-mixture-3D.csv size=500 dimension=3 description=[X0,X1,X2] data=[[0.523496,-0.65085,3.4227],[-3.33781,2.1485,-2.61978],[1.06029,-1.95534,3.70336],...,[-0.942375,2.07842,-2.26177],[-0.339844,2.21172,-1.61104],[1.43532,-0.747831,2.33587]]

# %%
mp = MatrixPlot(sample)
_ = mp.draw()

# %% [markdown]
# We can draw the distribution on the diagonal.

# %%
ks = ot.KernelSmoothing()
distribution = ks.build(sample)
mp = MatrixPlot(sample,distribution)
_ = mp.draw()
