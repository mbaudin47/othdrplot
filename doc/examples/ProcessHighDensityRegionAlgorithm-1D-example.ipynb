# %% [markdown]
# # HDR Plot

# %% [markdown]
# The *El Niño* dataset consists of 60 years worth of averaged monthly sea surface temperature (SST) in degrees Celcius of the Pacific Ocean at 0-10 deg South and 90-80 deg West between 1950 and 2007.
# Years 1982-83 and 1997-98 are outliers; these are the years where *El Niño* (a climate pattern characterized by warming up of the sea surface and higher air pressures) occurred with unusual intensity.
#
# Source: NOAA - ERSSTv5 - Nino 1+2 at http://www.cpc.ncep.noaa.gov/data/indices/

# %%
import os
import openturns as ot
import othdrplot as othdr
import openturns.viewer as otv
import numpy as np

# %% [markdown]
# The minimum volume level set computation requires a sampling which can be costly with the default value of the parameters, due to a huge sampling size. Hence, we reduce it to 10000.

# %%
n_samples = 10000
ot.ResourceMap.SetAsBool("Distribution-MinimumVolumeLevelSetBySampling", True)
ot.ResourceMap.SetAsUnsignedInteger(
    "Distribution-MinimumVolumeLevelSetSamplingSize", n_samples
)

# %% [markdown]
# Load the dataset.

# %%
basename = "sstoi.indices.txt"
filename = os.path.join(othdr.__path__[0], "data", basename)
separatorstr = " "
data = ot.Sample.ImportFromTextFile(filename, separatorstr)
data.setDescription(
    [
        "YR",
        "MON",
        "NINO1+2",
        "ANOM",
        "NINO3",
        "ANOM",
        "NINO4",
        "ANOM",
        "NINO3.4",
        "ANOM",
    ]
)
number_of_rows = data.getSize()
number_of_years = int(number_of_rows / 12.0)
total_column = np.array(data[:, 2]).reshape((number_of_years, 12))
data = ot.Sample(total_column)
data.setDescription(
    ["Jan", "Fev", "Mar", "Apr", "May", "Jun", "Jui", "Aug", "Sep", "Oct", "Nov", "Dec"]
)
data[:5]
# Out:
# class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=5 dimension=12 description=[Jan,Fev,Mar,Apr,May,Jun,Jui,Aug,Sep,Oct,Nov,Dec] data=[[24.29,25.49,25.21,24.5,23.97,22.89,22.47,21.75,21.8,22.94,24.59,26.13],[27.42,28.09,28.68,28.56,28.19,27.44,25.95,23.78,22.24,21.86,21.9,23.01],[24.18,25.18,26,25.16,23.23,21.96,21.24,20.17,20.37,20.52,21.5,22.58],[23.59,24.87,25.74,24.25,22.29,21.75,20.44,19.29,19.44,19.9,20.69,22.4],[24.61,26.06,25.91,24.58,23.38,21.98,21.12,20.97,20.44,21.07,22.03,23]]

# %%
graph = ot.Graph(basename, "Month", "Temperature (°C)", True)
for i in range(number_of_years):
    curve = ot.Curve(range(1, 13), data[i])
    graph.add(curve)
graph.setColors(ot.DrawableImplementation_BuildRainbowPalette(number_of_years))
graph
# Out:
# class=Graph name=sstoi.indices.txt implementation=class=GraphImplementation name=sstoi.indices.txt title=sstoi.indices.txt xTitle=Month yTitle=Temperature (°C) axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[1,24.29],[2,25.49],[3,25.21],[4,24.5],[5,23.97],[6,22.89],[7,22.47],[8,21.75],[9,21.8],[10,22.94],[11,24.59],[12,26.13]] color=#ff0000 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[1,27.42],[2,28.09],[3,28.68],[4,28.56],[5,28.19],[6,27.44],[7,25.95],[8,23.78],[9,22.24],[10,21.86],[11,21.9],[12,23.01]] color=#ff8000 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[1,24.18],[2,25.18],[3,26],[4,25.16],[5,23.23],[6,21.96],[7,21.24],[8,20.17],[9,20.37],[10,20.52],[11,21.5],[12,22.58]] color=#ffff00 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[1,23.59],[2,24.87],[3,25.74],[4,24.25],[5,22.29],[6,21.75],[7,20.44],[8,19.29],[9,19.44],[10,19.9],[11,20.69],[12,22.4]] color=#80ff00 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[1,24.61],[2,26.06],[3,25.91],[4,24.58],[5,23.38],[6,21.98],[7,21.12],[8,20.97],[9,20.44],[10,21.07],[11,22.03],[12,23]] color=#00ff00 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[1,25.3],[2,27.14],[3,28.01],[4,27.17],[5,25.58],[6,24.06],[7,22.78],[8,21.73],[9,21.45],[10,22.39],[11,22.63],[12,23.47]] color=#00ff80 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[1,24.64],[2,25.74],[3,25.78],[4,24.54],[5,23.6],[6,21.27],[7,20.26],[8,19.12],[9,19.19],[10,19.5],[11,20.55],[12,21.8]] color=#00ffff fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[1,24.09],[2,26.26],[3,26.66],[4,25.63],[5,23.18],[6,22],[7,21.12],[8,20.32],[9,19.87],[10,20.33],[11,21.31],[12,22.19]] color=#0080ff fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[1,24.02],[2,25.88],[3,26.16 ...

# %% [markdown]
# Create the mesh.

# %%
print("Number of dates : %d" % (data.getDimension()))
print("Number of fields : %d" % (data.getSize()))
# Out:
# Number of dates : 12
# Number of fields : 39

# %%
n_nodes = data.getDimension()
mesher = ot.IntervalMesher([n_nodes - 1])
interval = ot.Interval([0.0], [1.0])
mesh = mesher.build(interval)
mesh.draw()
# Out:
# class=Graph name=Mesh Unnamed implementation=class=GraphImplementation name=Mesh Unnamed title=Mesh Unnamed xTitle= yTitle=v0 axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=11 elements data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0,0],[0.0909091,0]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0.0909091,0],[0.181818,0]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0.181818,0],[0.272727,0]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0.272727,0],[0.363636,0]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0.363636,0],[0.454545,0]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0.454545,0],[0.545455,0]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0.545455,0],[0.636364,0]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0.636364,0],[0.727273,0]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0.727273,0],[0.818182,0]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0.818182,0],[0.909091,0]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0.909091,0],[1,0]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed ...

# %% [markdown]
# Create the ProcessSample from the data.

# %%
n_fields = data.getSize()
d_fields = 1
processSample = ot.ProcessSample(mesh, n_fields, d_fields)
for i in range(n_fields):
    trajectory = ot.Sample([[x] for x in data[i, :]])
    processSample[i] = ot.Field(mesh, trajectory)

# %% [markdown]
# We reduce the dimension to 1 component: this is quite extreme.

# %%
# KL decomposition
reduction = othdr.KarhunenLoeveDimensionReductionAlgorithm(processSample, 1)
reduction.run()
reducedComponents = reduction.getReducedComponents()

# Distribution fit in reduced space
ks = ot.KernelSmoothing()
reducedDistribution = ks.build(reducedComponents)

# %% [markdown]
# We can visualize the sample and the distribution.

# %%
othdr.DrawUnivariateSampleDistribution(reducedComponents, reducedDistribution)
# Out:
# class=Graph name=pdf as a function of C0 implementation=class=GraphImplementation name=pdf as a function of C0 title= xTitle=C0 yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=C0 PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[
] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2,class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=39 dimension=2 data=[[22.5362,0],[24.5201,0],[21.343,0],[20.6817,0],[21.5366,0],[22.9904,0],[20.712,0],[21.3519,0],[21.4369,0],[22.0266,0],[22.4097,0],[22.3071,0],[21.4534,0],[21.2846,0],[20.6387,0],[24.7849,0],[23.4512,0],[20.907,0],[21.3243,0],[21.2241,0],[21.866,0],[21.1626,0],[21.243,0],[21.3427,0],[22.1812,0],[20.4205,0],[22.2816,0],[22.3641,0],[20.9887,0],[21.8335,0],[22.4222,0],[20.9556,0],[22.6303,0],[23.864,0],[22.1788,0],[21.7778,0],[21.6161,0],[21.5918,0],[21.276,0]] color=blue fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1]

# %% [markdown]
# The `HighDensityRegionAlgorithm` class plots the high density regions in 1 dimension.

# %%
mydp = othdr.HighDensityRegionAlgorithm(
    reducedComponents, reducedDistribution, [0.8, 0.5]
)
mydp.run()
grid = mydp.draw(drawInliers=True)
view = otv.View(grid).getFigure().set_size_inches(6.0, 6.0)

# %%
hdr = othdr.ProcessHighDensityRegionAlgorithm(processSample, reducedComponents, reducedDistribution, [0.8, 0.5])
hdr.run()

# %%
grid = hdr.draw()
view = otv.View(grid).getFigure().set_size_inches(6.0, 6.0)

# %%
hdr.draw(drawInliers=True)
# Out:
# class=Graph name=Outliers at $\alpha$=0.80 implementation=class=GraphImplementation name=Outliers at $\alpha$=0.80 title=Outliers at $\alpha$=0.80 xTitle= yTitle= axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[0,27.42],[0.0909091,28.09],[0.181818,28.68],[0.272727,28.56],[0.363636,28.19],[0.454545,27.44],[0.545455,25.95],[0.636364,23.78],[0.727273,22.24],[0.818182,21.86],[0.909091,21.9],[1,23.01]] color=firebrick3 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[0,25.3],[0.0909091,27.14],[0.181818,28.01],[0.272727,27.17],[0.363636,25.58],[0.454545,24.06],[0.545455,22.78],[0.636364,21.73],[0.727273,21.45],[0.818182,22.39],[0.909091,22.63],[1,23.47]] color=firebrick3 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[0,23.67],[0.0909091,25.74],[0.181818,26.95],[0.272727,26.64],[0.363636,26.71],[0.454545,26.27],[0.545455,25.59],[0.636364,24.8],[0.727273,24.4],[0.818182,24.58],[0.909091,25.63],[1,26.92]] color=firebrick3 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[0,28.22],[0.0909091,28.98],[0.181818,29.15],[0.272727,28.61],[0.363636,27.69],[0.454545,25.18],[0.545455,23.43],[0.636364,21.77],[0.727273,20.87],[0.818182,21.16],[0.909091,21.43],[1,22.56]] color=firebrick3 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[0,24.99],[0.0909091,26.24],[0.181818,25.74],[0.272727,24.3],[0.363636,22.73],[0.454545,21.59],[0.545455,20.27],[0.636364,19.16],[0.727273,18.57],[0.818182,18.8],[0.909091,19.49],[1,21.02]] color=firebrick3 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[0,24.13],[0.0909091,25.59],[0.181818,26.69],[0.272727,26.95],[0.363636,26.71],[0.454545,25.42],[0.545455,24.48],[0.636364,22.88],[0.727273,22.91],[0.818182,23.31],[0.909091,23.83],[1,25.01]] color=firebrick3 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=12 dimension=2 data=[[0,24.29],[0.0909091,25.49],[0.181818,25.21],[0.272727,24.5],[0.363636,23.97],[0.454545,22.89],[0.545455,22.47],[0.636364,21.75],[0.727273,21.8],[0.818182,22.94],[0.909091,24.59],[1,26.13]] color=forestgreen fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImp ...

# %%
print("Outliers trajectories")
outlierIndices = hdr.computeIndices()
outlierIndices
# Out:
# Outliers trajectories
# [1, 5, 15, 16, 25, 33]
